# %%
import os
import shutil
import pandas as pd

# %%
dataset_path = "../datasets/lsa64_dataset_openpose_80_frames_augmented.csv"
input_path = "../dataset_output/lsa64_images/all_landmarks/imgs/"
output_path = "../dataset_output/lsa64_images/all_landmarks/imgs_lopo/"

# %%
train = pd.read_csv(dataset_path)
train = train.drop("Unnamed: 0", axis=1)

# %%
df = train[train["frame"] == 1]

# %%
df["person"] = df["video_name"].apply(lambda i: i.split("_")[1])
# Out:
# C:\Users\duduu\AppData\Local\Temp\ipykernel_2012\4225238675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["person"] = df["video_name"].apply(lambda i: i.split("_")[1])

# %%
df
# Out:
#         category                  video_name  frame  hand_0_0_x  hand_0_0_y  \
# 0              1             001_001_001.mp4      1    0.557995    0.944853
# 81             1             001_001_002.mp4      1    0.511980    0.979820
# 161            1             001_001_003.mp4      1    0.518630    0.981148
# 241            1             001_001_004.mp4      1    0.516131    0.982689
# 320            1             001_001_005.mp4      1    0.515440    0.981388
# ...          ...                         ...    ...         ...         ...
# 665201         9  augmented3-009_008_004.mp4      1    0.483578    1.024056
# 665281         9  augmented3-009_007_004.mp4      1    0.036369   -0.035257
# 665361         9  augmented3-009_008_004.mp4      1    0.480549    1.003873
# 665441         9  augmented3-009_005_004.mp4      1    0.516685    0.910780
# 665521         9  augmented3-009_005_002.mp4      1    0.496750    0.922962
#
#         hand_0_0_z  hand_0_1_x  hand_0_1_y  hand_0_1_z  hand_0_2_x  ...  \
# 0         0.363025    0.538670    0.990662    0.072256    0.526957  ...
# 81        0.223309    0.489175    1.005722    0.035948    0.472071  ...
# 161       0.194982    0.495274    1.004716    0.043596    0.464973  ...
# 241       0.161486    0.492562    1.009868    0.034212    0.470903  ...
# 320       0.148118    0.497610    1.010822    0.035876    0.474049  ...
# ...            ...         ...         ...         ...         ...  ...
# 665201    0.229648    0.462933    1.047504    0.043296    0.447742  ...
# 665281    0.000000    0.036369   -0.035257    0.000000    0.036369  ...
# 665361    0.223426    0.460585    1.026792    0.042123    0.446116  ...
# 665441    0.204581    0.497952    0.935637    0.050766    0.467465  ...
# 665521    0.183652    0.478163    0.948648    0.055976    0.474581  ...
#
#         pose_22_z  pose_23_x  pose_23_y  pose_23_z  pose_24_x  pose_24_y  \
# 0             0.0   0.000000   0.000000        0.0   0.000000   0.000000
# 81            0.0   0.000000   0.000000        0.0   0.000000   0.000000
# 161           0.0   0.000000   0.000000        0.0   0.000000   0.000000
# 241           0.0   0.000000   0.000000        0.0   0.000000   0.000000
# 320           0.0   0.000000   0.000000        0.0   0.000000   0.000000
# ...           ...        ...        ...        ...        ...        ...
# 665201        0.0   0.047126  -0.057287        0.0   0.047126  -0.057287
# 665281        0.0   0.036369  -0.035257        0.0   0.036369  -0.035257
# 665361        0.0   0.050326  -0.045897        0.0   0.050326  -0.045897
# 665441        0.0  -0.056419   0.020361        0.0  -0.056419   0.020361
# 665521        0.0  -0.039255  -0.005659        0.0  -0.039255  -0.005659
#
#         pose_24_z  missing_hand  missing_face  person
# 0             0.0         False         False     001
# 81            0.0         False         False     001
# 161           0.0         False         False     001
# 241           0.0         False         False     001
# 320           0.0         False         False     001
# ...           ...           ...           ...     ...
# 665201        0.0         False         False     008
# 665281        0.0         False         False     007
# 665361        0.0         False         False     008
# 665441        0.0         False         False     005
# 665521        0.0         False         False     005
#
# [8320 rows x 417 columns]

# %%
people = df["person"].unique()
validate_people = people[-2:]
test_people = people[-4:-2]
train_people = people[:-4]

# %%
def create_folder(path):
    if not os.path.exists(path):
        os.mkdir(path)

# %%
def copy_file(video_name, category, destination):
    src = os.path.join(input_path, category, video_name + ".png")
    dst = os.path.join(output_path, destination, category, video_name + ".png")
    create_folder(os.path.join(output_path, destination, category))
    shutil.copyfile(src, dst)

# %%
df_train = df[df["person"].isin(train_people)]

# %%
df_test = df[(df["person"].isin(test_people) & (~df["video_name"].str.startswith("augmented")))]
df_validate = df[(df["person"].isin(validate_people) & (~df["video_name"].str.startswith("augmented")))]

# %%
def copy_df(df_copy, destination):
    for row in df_copy.iterrows():
        video_name = row[1]["video_name"]
        category = str(row[1]["category"])
        copy_file(video_name, category, destination)

# %%
copy_df(df_train, "train")
copy_df(df_test, "test")
copy_df(df_validate, "validate")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 copy_df(df_train, "train")
#       2 copy_df(df_test, "test")
#       3 copy_df(df_validate, "validate")
#
# Cell In[12], line 5, in copy_df(df_copy, destination)
#       3 video_name = row[1]["video_name"]
#       4 category = str(row[1]["category"])
# ----> 5 copy_file(video_name, category, destination)
#
# Cell In[9], line 4, in copy_file(video_name, category, destination)
#       2 src = os.path.join(input_path, category, video_name + ".png")
#       3 dst = os.path.join(output_path, destination, category, video_name + ".png")
# ----> 4 create_folder(os.path.join(output_path, destination, category))
#       5 shutil.copyfile(src, dst)
#
# Cell In[8], line 3, in create_folder(path)
#       1 def create_folder(path):
#       2     if not os.path.exists(path):
# ----> 3         os.mkdir(path)
#
# FileNotFoundError: [WinError 3] O sistema não pode encontrar o caminho especificado: '../dataset_output/lsa64_images/all_landmarks/imgs_lopo/train\\1'

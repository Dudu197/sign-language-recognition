# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt

# %%
base_path = "../../datasets/google asl/"
output_path = "../dataset_output/google_asl/imgs/"

# %%
train = pd.read_csv(base_path + "train.csv")

# %%
train
# Out:
#                                                 path  participant_id  \
# 0      train_landmark_files/26734/1000035562.parquet           26734
# 1      train_landmark_files/28656/1000106739.parquet           28656
# 2       train_landmark_files/16069/100015657.parquet           16069
# 3      train_landmark_files/25571/1000210073.parquet           25571
# 4      train_landmark_files/62590/1000240708.parquet           62590
# ...                                              ...             ...
# 94472   train_landmark_files/53618/999786174.parquet           53618
# 94473   train_landmark_files/26734/999799849.parquet           26734
# 94474   train_landmark_files/25571/999833418.parquet           25571
# 94475   train_landmark_files/29302/999895257.parquet           29302
# 94476   train_landmark_files/36257/999962374.parquet           36257
#
#        sequence_id    sign
# 0       1000035562    blow
# 1       1000106739    wait
# 2        100015657   cloud
# 3       1000210073    bird
# 4       1000240708    owie
# ...            ...     ...
# 94472    999786174   white
# 94473    999799849    have
# 94474    999833418  flower
# 94475    999895257    room
# 94476    999962374   happy
#
# [94477 rows x 4 columns]

# %%
train["sign"].value_counts()
# Out:
# listen    415
# look      414
# shhh      411
# donkey    410
# mouse     408
#          ...
# dance     312
# person    312
# beside    310
# vacuum    307
# zipper    299
# Name: sign, Length: 250, dtype: int64

# %%
signs = list(train["sign"].unique())

# %%
signs
# Out:
# ['blow',
#  'wait',
#  'cloud',
#  'bird',
#  'owie',
#  'duck',
#  'minemy',
#  'lips',
#  'flower',
#  'time',
#  'vacuum',
#  'apple',
#  'puzzle',
#  'mitten',
#  'there',
#  'dry',
#  'shirt',
#  'owl',
#  'yellow',
#  'not',
#  'zipper',
#  'clean',
#  'closet',
#  'quiet',
#  'have',
#  'brother',
#  'clown',
#  'cheek',
#  'cute',
#  'store',
#  'shoe',
#  'wet',
#  'see',
#  'empty',
#  'fall',
#  'balloon',
#  'frenchfries',
#  'finger',
#  'same',
#  'cry',
#  'hungry',
#  'orange',
#  'milk',
#  'go',
#  'drawer',
#  'TV',
#  'another',
#  'giraffe',
#  'wake',
#  'bee',
#  'bad',
#  'can',
#  'say',
#  'callonphone',
#  'finish',
#  'old',
#  'backyard',
#  'sick',
#  'look',
#  'that',
#  'black',
#  'yourself',
#  'open',
#  'alligator',
#  'moon',
#  'find',
#  'pizza',
#  'shhh',
#  'fast',
#  'jacket',
#  'scissors',
#  'now',
#  'man',
#  'sticky',
#  'jump',
#  'sleep',
#  'sun',
#  'first',
#  'grass',
#  'uncle',
#  'fish',
#  'cowboy',
#  'snow',
#  'dryer',
#  'green',
#  'bug',
#  'nap',
#  'feet',
#  'yucky',
#  'morning',
#  'sad',
#  'face',
#  'penny',
#  'gift',
#  'night',
#  'hair',
#  'who',
#  'think',
#  'brown',
#  'mad',
#  'bed',
#  'drink',
#  'stay',
#  'flag',
#  'tooth',
#  'awake',
#  'thankyou',
#  'hot',
#  'like',
#  'where',
#  'hesheit',
#  'potty',
#  'down',
#  'stuck',
#  'no',
#  'head',
#  'food',
#  'pretty',
#  'nuts',
#  'animal',
#  'frog',
#  'beside',
#  'noisy',
#  'water',
#  'weus',
#  'happy',
#  'white',
#  'bye',
#  'high',
#  'fine',
#  'boat',
#  'all',
#  'tiger',
#  'pencil',
#  'sleepy',
#  'grandma',
#  'chocolate',
#  'haveto',
#  'radio',
#  'farm',
#  'any',
#  'zebra',
#  'rain',
#  'toy',
#  'donkey',
#  'lion',
#  'drop',
#  'many',
#  'bath',
#  'aunt',
#  'will',
#  'hate',
#  'on',
#  'pretend',
#  'kitty',
#  'fireman',
#  'before',
#  'doll',
#  'stairs',
#  'kiss',
#  'loud',
#  'hen',
#  'listen',
#  'give',
#  'wolf',
#  'dad',
#  'gum',
#  'hear',
#  'refrigerator',
#  'outside',
#  'cut',
#  'underwear',
#  'please',
#  'child',
#  'smile',
#  'pen',
#  'yesterday',
#  'horse',
#  'pig',
#  'table',
#  'eye',
#  'snack',
#  'story',
#  'police',
#  'arm',
#  'talk',
#  'grandpa',
#  'tongue',
#  'pool',
#  'girl',
#  'up',
#  'better',
#  'tree',
#  'dance',
#  'close',
#  'taste',
#  'chin',
#  'ride',
#  'because',
#  'if',
#  'cat',
#  'why',
#  'carrot',
#  'dog',
#  'mouse',
#  'jeans',
#  'shower',
#  'later',
#  'mom',
#  'nose',
#  'yes',
#  'airplane',
#  'book',
#  'blue',
#  'icecream',
#  'garbage',
#  'tomorrow',
#  'red',
#  'cow',
#  'person',
#  'puppy',
#  'cereal',
#  'touch',
#  'mouth',
#  'boy',
#  'thirsty',
#  'make',
#  'for',
#  'glasswindow',
#  'into',
#  'read',
#  'every',
#  'bedroom',
#  'napkin',
#  'ear',
#  'toothbrush',
#  'home',
#  'pajamas',
#  'hello',
#  'helicopter',
#  'lamp',
#  'room',
#  'dirty',
#  'chair',
#  'hat',
#  'elephant',
#  'after',
#  'car',
#  'hide',
#  'goose']

# %%
export_signs = signs[70:]
export_signs
# Out:
# ['scissors',
#  'now',
#  'man',
#  'sticky',
#  'jump',
#  'sleep',
#  'sun',
#  'first',
#  'grass',
#  'uncle',
#  'fish',
#  'cowboy',
#  'snow',
#  'dryer',
#  'green',
#  'bug',
#  'nap',
#  'feet',
#  'yucky',
#  'morning',
#  'sad',
#  'face',
#  'penny',
#  'gift',
#  'night',
#  'hair',
#  'who',
#  'think',
#  'brown',
#  'mad',
#  'bed',
#  'drink',
#  'stay',
#  'flag',
#  'tooth',
#  'awake',
#  'thankyou',
#  'hot',
#  'like',
#  'where',
#  'hesheit',
#  'potty',
#  'down',
#  'stuck',
#  'no',
#  'head',
#  'food',
#  'pretty',
#  'nuts',
#  'animal',
#  'frog',
#  'beside',
#  'noisy',
#  'water',
#  'weus',
#  'happy',
#  'white',
#  'bye',
#  'high',
#  'fine',
#  'boat',
#  'all',
#  'tiger',
#  'pencil',
#  'sleepy',
#  'grandma',
#  'chocolate',
#  'haveto',
#  'radio',
#  'farm',
#  'any',
#  'zebra',
#  'rain',
#  'toy',
#  'donkey',
#  'lion',
#  'drop',
#  'many',
#  'bath',
#  'aunt',
#  'will',
#  'hate',
#  'on',
#  'pretend',
#  'kitty',
#  'fireman',
#  'before',
#  'doll',
#  'stairs',
#  'kiss',
#  'loud',
#  'hen',
#  'listen',
#  'give',
#  'wolf',
#  'dad',
#  'gum',
#  'hear',
#  'refrigerator',
#  'outside',
#  'cut',
#  'underwear',
#  'please',
#  'child',
#  'smile',
#  'pen',
#  'yesterday',
#  'horse',
#  'pig',
#  'table',
#  'eye',
#  'snack',
#  'story',
#  'police',
#  'arm',
#  'talk',
#  'grandpa',
#  'tongue',
#  'pool',
#  'girl',
#  'up',
#  'better',
#  'tree',
#  'dance',
#  'close',
#  'taste',
#  'chin',
#  'ride',
#  'because',
#  'if',
#  'cat',
#  'why',
#  'carrot',
#  'dog',
#  'mouse',
#  'jeans',
#  'shower',
#  'later',
#  'mom',
#  'nose',
#  'yes',
#  'airplane',
#  'book',
#  'blue',
#  'icecream',
#  'garbage',
#  'tomorrow',
#  'red',
#  'cow',
#  'person',
#  'puppy',
#  'cereal',
#  'touch',
#  'mouth',
#  'boy',
#  'thirsty',
#  'make',
#  'for',
#  'glasswindow',
#  'into',
#  'read',
#  'every',
#  'bedroom',
#  'napkin',
#  'ear',
#  'toothbrush',
#  'home',
#  'pajamas',
#  'hello',
#  'helicopter',
#  'lamp',
#  'room',
#  'dirty',
#  'chair',
#  'hat',
#  'elephant',
#  'after',
#  'car',
#  'hide',
#  'goose']

# %%
len(export_signs)
# Out:
# 180

# %%
df_signs = train[train["sign"].isin(export_signs)]

# %%
df_signs
# Out:
#                                                 path  participant_id  \
# 82      train_landmark_files/26734/100328364.parquet           26734
# 83     train_landmark_files/36257/1003335907.parquet           36257
# 86     train_landmark_files/53618/1003370644.parquet           53618
# 87      train_landmark_files/2044/1003433922.parquet            2044
# 88     train_landmark_files/55372/1003483016.parquet           55372
# ...                                              ...             ...
# 94470   train_landmark_files/61333/999641996.parquet           61333
# 94471   train_landmark_files/25571/999740509.parquet           25571
# 94472   train_landmark_files/53618/999786174.parquet           53618
# 94475   train_landmark_files/29302/999895257.parquet           29302
# 94476   train_landmark_files/36257/999962374.parquet           36257
#
#        sequence_id      sign
# 82       100328364  scissors
# 83      1003335907       now
# 86      1003370644       man
# 87      1003433922    sticky
# 88      1003483016      jump
# ...            ...       ...
# 94470    999641996       why
# 94471    999740509  scissors
# 94472    999786174     white
# 94475    999895257      room
# 94476    999962374     happy
#
# [68042 rows x 4 columns]

# %%
def get_axis_df(x, axis):
    x_values = {}
    for l in x["landmark"].unique():
        x_values[l] = x[x["landmark"] == l][axis].values
    x_values
    return pd.DataFrame.from_dict(x_values).T

# %%
def normalize_landmark_name(name):
    splited_name = name.split("-")
    landmark_name = splited_name[1]
    landmark_number = splited_name[2].rjust(3, "0")
    return f"{landmark_name}-{landmark_number}"

# %%
def create_folder(path):
    if not os.path.exists(path):
        os.mkdir(path)

# %%
def landmarks_to_image(x, y, n=3, normalize=False):
    # Remove cols until the width is multiple of n
    width = x.shape[1]
    if width % n != 0:
        extra_cols = width % n
        x = x[:, : width - extra_cols]
        y = y[:, : width - extra_cols]

    X = np.reshape(x, (x.shape[0], -1, n))
    Y = np.reshape(y, (y.shape[0], -1, n))
    I = np.concatenate([X, Y], axis=1)
    return I

# %%
def normalize_axis(axis):
    axis[axis < 0] = 0
    axis[axis > 1] = 1
    return axis

# %%
total_videos = len(df_signs)
current_video = 0
for i in df_signs.iterrows():
    current_video += 1
    if current_video % 500 == 0:
        print("Current Video:", current_video, "of", total_videos)
    row = i[1]
    df = pd.read_parquet(base_path + row["path"])
    df = df[df["type"].isin(["left_hand", "right_hand"])]
    df["landmark"] = df["row_id"].apply(lambda i: normalize_landmark_name(i))
    df = df.sort_values("landmark")
    x = get_axis_df(df, "x")
    y = get_axis_df(df, "y")
    x = x.to_numpy()
    y = y.to_numpy()
    x = normalize_axis(x)
    y = normalize_axis(y)
    image = landmarks_to_image(x, y)
    save_path = os.path.join(output_path, row["sign"], f"{row['participant_id']}-{row['sequence_id']}.png")
    create_folder(os.path.join(output_path, row["sign"]))
    try:
        plt.imsave(save_path, image)
    except:
        print("Error saving", save_path)
# Out:
# Current Video: 500 of 68042
# Current Video: 1000 of 68042
# Error saving ../dataset_output/google_asl/imgs/yucky\4718-1087675974.png
# Current Video: 1500 of 68042
# Current Video: 2000 of 68042
# Error saving ../dataset_output/google_asl/imgs/bug\30680-1123274265.png
# Error saving ../dataset_output/google_asl/imgs/bath\26734-1142420711.png
# Current Video: 2500 of 68042
# Current Video: 3000 of 68042
# Error saving ../dataset_output/google_asl/imgs/car\49445-1199372112.png
# Current Video: 3500 of 68042
# Current Video: 4000 of 68042
# Current Video: 4500 of 68042
# Current Video: 5000 of 68042
# Error saving ../dataset_output/google_asl/imgs/after\4718-1304860276.png
# Current Video: 5500 of 68042
# Current Video: 6000 of 68042
# Error saving ../dataset_output/google_asl/imgs/mouse\30680-1355275858.png
# Error saving ../dataset_output/google_asl/imgs/zebra\27610-1374178443.png
# Current Video: 6500 of 68042
# Current Video: 7000 of 68042
# Current Video: 7500 of 68042
# Error saving ../dataset_output/google_asl/imgs/kiss\61333-1447328137.png
# Current Video: 8000 of 68042
# Error saving ../dataset_output/google_asl/imgs/toothbrush\30680-1472665840.png
# Current Video: 8500 of 68042
# Error saving ../dataset_output/google_asl/imgs/scissors\30680-1489504656.png
# Current Video: 9000 of 68042
# Current Video: 9500 of 68042
# Current Video: 10000 of 68042
# Error saving ../dataset_output/google_asl/imgs/jump\32319-1589231716.png
# Current Video: 10500 of 68042
# Error saving ../dataset_output/google_asl/imgs/beside\30680-1633415588.png
# Current Video: 11000 of 68042
# Current Video: 11500 of 68042
# Current Video: 12000 of 68042
# Error saving ../dataset_output/google_asl/imgs/on\49445-16972739.png
# Current Video: 12500 of 68042
# Error saving ../dataset_output/google_asl/imgs/toothbrush\61333-1736098156.png
# Error saving ../dataset_output/google_asl/imgs/yucky\28656-1742994114.png
# Error saving ../dataset_output/google_asl/imgs/hat\30680-1748845942.png
# Current Video: 13000 of 68042
# Error saving ../dataset_output/google_asl/imgs/person\36257-1754426882.png
# Current Video: 13500 of 68042
# Error saving ../dataset_output/google_asl/imgs/zebra\4718-1786369278.png
# Current Video: 14000 of 68042
# Current Video: 14500 of 68042
# Error saving ../dataset_output/google_asl/imgs/many\4718-1853353999.png
# Current Video: 15000 of 68042
# Current Video: 15500 of 68042
# Current Video: 16000 of 68042
# Current Video: 16500 of 68042
# Error saving ../dataset_output/google_asl/imgs/jeans\53618-1960582597.png
# Current Video: 17000 of 68042
# Error saving ../dataset_output/google_asl/imgs/flag\4718-1990900569.png
# Current Video: 17500 of 68042
# Error saving ../dataset_output/google_asl/imgs/pretend\4718-2029151171.png
# Error saving ../dataset_output/google_asl/imgs/boat\37055-2029228854.png
# Current Video: 18000 of 68042
# Current Video: 18500 of 68042
# Error saving ../dataset_output/google_asl/imgs/chocolate\4718-2063434570.png
# Current Video: 19000 of 68042
# Current Video: 19500 of 68042
# Current Video: 20000 of 68042
# Current Video: 20500 of 68042
# Error saving ../dataset_output/google_asl/imgs/into\26734-2189530106.png
# Current Video: 21000 of 68042
# Current Video: 21500 of 68042
# Error saving ../dataset_output/google_asl/imgs/animal\49445-2244847113.png
# Error saving ../dataset_output/google_asl/imgs/helicopter\4718-2249788250.png
# Current Video: 22000 of 68042
# Current Video: 22500 of 68042
# Current Video: 23000 of 68042
# Error saving ../dataset_output/google_asl/imgs/hat\36257-2319732979.png
# Current Video: 23500 of 68042
# Current Video: 24000 of 68042
# Error saving ../dataset_output/google_asl/imgs/pajamas\30680-2378809274.png
# Current Video: 24500 of 68042
# Current Video: 25000 of 68042
# Error saving ../dataset_output/google_asl/imgs/into\4718-2430342081.png
# Current Video: 25500 of 68042
# Error saving ../dataset_output/google_asl/imgs/hello\4718-2470490515.png
# Current Video: 26000 of 68042
# Current Video: 26500 of 68042
# Current Video: 27000 of 68042
# Error saving ../dataset_output/google_asl/imgs/cut\29302-2532887554.png
# Current Video: 27500 of 68042
# Current Video: 28000 of 68042
# Current Video: 28500 of 68042
# Error saving ../dataset_output/google_asl/imgs/book\4718-2642768119.png
# Current Video: 29000 of 68042
# Current Video: 29500 of 68042
# Current Video: 30000 of 68042
# Error saving ../dataset_output/google_asl/imgs/morning\22343-2700005588.png
# Current Video: 30500 of 68042
# Current Video: 31000 of 68042
# Error saving ../dataset_output/google_asl/imgs/into\61333-275600003.png
# Current Video: 31500 of 68042
# Current Video: 32000 of 68042
# Current Video: 32500 of 68042
# Current Video: 33000 of 68042
# Error saving ../dataset_output/google_asl/imgs/food\4718-287293243.png
# Current Video: 33500 of 68042
# Current Video: 34000 of 68042
# Error saving ../dataset_output/google_asl/imgs/awake\4718-2945528541.png
# Error saving ../dataset_output/google_asl/imgs/penny\4718-2953207517.png
# Current Video: 34500 of 68042
# Error saving ../dataset_output/google_asl/imgs/first\4718-2971605826.png
# Current Video: 35000 of 68042
# Current Video: 35500 of 68042
# Error saving ../dataset_output/google_asl/imgs/chair\30680-3014208870.png
# Error saving ../dataset_output/google_asl/imgs/wolf\4718-3023321969.png
# Current Video: 36000 of 68042
# Current Video: 36500 of 68042
# Current Video: 37000 of 68042
# Current Video: 37500 of 68042
# Error saving ../dataset_output/google_asl/imgs/grandma\4718-315243057.png
# Current Video: 38000 of 68042
# Current Video: 38500 of 68042
# Current Video: 39000 of 68042
# Current Video: 39500 of 68042
# Error saving ../dataset_output/google_asl/imgs/hate\4718-3241469039.png
# Current Video: 40000 of 68042
# Error saving ../dataset_output/google_asl/imgs/book\36257-3275736028.png
# Error saving ../dataset_output/google_asl/imgs/chair\4718-3287144487.png
# Current Video: 40500 of 68042
# Current Video: 41000 of 68042
# Error saving ../dataset_output/google_asl/imgs/book\55372-3328176895.png
# Current Video: 41500 of 68042
# Current Video: 42000 of 68042
# Current Video: 42500 of 68042
# Error saving ../dataset_output/google_asl/imgs/stairs\4718-3434276366.png
# Current Video: 43000 of 68042
# Current Video: 43500 of 68042
# Error saving ../dataset_output/google_asl/imgs/donkey\4718-347636679.png
# Error saving ../dataset_output/google_asl/imgs/donkey\53618-3484609165.png
# Current Video: 44000 of 68042
# Error saving ../dataset_output/google_asl/imgs/give\28656-3503864148.png
# Current Video: 44500 of 68042
# Current Video: 45000 of 68042
# Error saving ../dataset_output/google_asl/imgs/bath\29302-3573883819.png
# Error saving ../dataset_output/google_asl/imgs/happy\4718-3578726346.png
# Current Video: 45500 of 68042
# Error saving ../dataset_output/google_asl/imgs/mad\29302-3607501072.png
# Current Video: 46000 of 68042
# Current Video: 46500 of 68042
# Current Video: 47000 of 68042
# Current Video: 47500 of 68042
# Current Video: 48000 of 68042
# Error saving ../dataset_output/google_asl/imgs/hello\4718-3732957229.png
# Current Video: 48500 of 68042
# Error saving ../dataset_output/google_asl/imgs/red\4718-3774444407.png
# Current Video: 49000 of 68042
# Current Video: 49500 of 68042
# Current Video: 50000 of 68042
# Error saving ../dataset_output/google_asl/imgs/snow\30680-38452751.png
# Current Video: 50500 of 68042
# Error saving ../dataset_output/google_asl/imgs/bed\22343-3875450866.png
# Error saving ../dataset_output/google_asl/imgs/taste\4718-3882566521.png
# Current Video: 51000 of 68042
# Error saving ../dataset_output/google_asl/imgs/chocolate\29302-3901454534.png
# Current Video: 51500 of 68042
# Current Video: 52000 of 68042
# Error saving ../dataset_output/google_asl/imgs/zebra\4718-3968923035.png
# Error saving ../dataset_output/google_asl/imgs/horse\4718-3972280055.png
# Error saving ../dataset_output/google_asl/imgs/head\30680-3976089770.png
# Current Video: 52500 of 68042
# Current Video: 53000 of 68042
# Error saving ../dataset_output/google_asl/imgs/no\4718-4023564833.png
# Error saving ../dataset_output/google_asl/imgs/arm\36257-4033330173.png
# Current Video: 53500 of 68042
# Current Video: 54000 of 68042
# Current Video: 54500 of 68042
# Current Video: 55000 of 68042
# Current Video: 55500 of 68042
# Error saving ../dataset_output/google_asl/imgs/pool\4718-415833925.png
# Current Video: 56000 of 68042
# Current Video: 56500 of 68042
# Current Video: 57000 of 68042
# Current Video: 57500 of 68042
# Current Video: 58000 of 68042
# Current Video: 58500 of 68042
# Current Video: 59000 of 68042
# Current Video: 59500 of 68042
# Error saving ../dataset_output/google_asl/imgs/airplane\4718-523187955.png
# Error saving ../dataset_output/google_asl/imgs/thirsty\36257-528586804.png
# Current Video: 60000 of 68042
# Current Video: 60500 of 68042
# Current Video: 61000 of 68042
# Error saving ../dataset_output/google_asl/imgs/read\26734-617950465.png
# Current Video: 61500 of 68042
# Current Video: 62000 of 68042
# Current Video: 62500 of 68042
# Current Video: 63000 of 68042
# Error saving ../dataset_output/google_asl/imgs/red\27610-708097964.png
# Current Video: 63500 of 68042
# Current Video: 64000 of 68042
# Current Video: 64500 of 68042
# Current Video: 65000 of 68042
# Current Video: 65500 of 68042
# Error saving ../dataset_output/google_asl/imgs/touch\32319-85953776.png
# Current Video: 66000 of 68042
# Current Video: 66500 of 68042

# %%
row
# Out:
# path              train_landmark_files/32319/2093201419.parquet
# participant_id                                            32319
# sequence_id                                          2093201419
# sign                                                        not
# Name: 26477, dtype: object

# %%
row
# Out:
# path              train_landmark_files/26734/1000035562.parquet
# participant_id                                            26734
# sequence_id                                          1000035562
# sign                                                       blow
# Name: 0, dtype: object

# %%
X = np.array_split(x, x.shape[1] // 3, axis=1)
X = np.stack(X, axis=1)
Y = np.array_split(y, y.shape[1] // 3, axis=1)
Y = np.stack(Y, axis=1)
X.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 2
#       1 X = np.array_split(x, x.shape[1] // 3, axis=1)
# ----> 2 X = np.stack(X, axis=1)
#       3 Y = np.array_split(y, y.shape[1] // 3, axis=1)
#       4 Y = np.stack(Y, axis=1)
#
# File <__array_function__ internals>:180, in stack(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\shape_base.py:426, in stack(arrays, axis, out)
#     424 shapes = {arr.shape for arr in arrays}
#     425 if len(shapes) != 1:
# --> 426     raise ValueError('all input arrays must have the same shape')
#     428 result_ndim = arrays[0].ndim + 1
#     429 axis = normalize_axis_index(axis, result_ndim)
#
# ValueError: all input arrays must have the same shape

# %%
plt.imshow(landmarks_to_image(x, y))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
x = df.copy()
x["landmark"] = df["row_id"].apply(lambda i: "-".join(i.split("-")[1:]))
x_values = {}
for l in x["landmark"].unique():
    x_values[l] = x[x["landmark"] == l]["x"].values
x_values
pd.DataFrame.from_dict(x_values).T
# x = x[["landmark", "x"]]
# x = pd.melt(x[["landmark", "x"]], id_vars=['landmark'], value_vars=['x'])
# x = x.set_index("landmark")
# x["x"].values.reshape(())
# Out:
#                      0         1         2         3         4         5   \
# face-0         0.494400  0.501150  0.498471  0.506406  0.507809  0.512282
# face-1         0.496017  0.492906  0.491770  0.496547  0.502923  0.505973
# face-2         0.500818  0.498327  0.497680  0.502239  0.508405  0.512122
# face-3         0.489788  0.487708  0.487321  0.491887  0.498103  0.502142
# face-4         0.495304  0.492322  0.491236  0.496049  0.502395  0.505442
# ...                 ...       ...       ...       ...       ...       ...
# right_hand-16  0.422241  0.440972  0.460872  0.467546  0.473871  0.473521
# right_hand-17  0.282980  0.304759  0.321579  0.326890  0.337585  0.325513
# right_hand-18  0.313736  0.335886  0.358558  0.365960  0.372476  0.352425
# right_hand-19  0.350728  0.377429  0.400531  0.403416  0.414791  0.390784
# right_hand-20  0.385796  0.416391  0.439078  0.438204  0.453951  0.431783
#
#                      6         7         8         9   ...        13  \
# face-0         0.519686  0.526654  0.534279  0.537974  ...  0.539496
# face-1         0.511610  0.515489  0.524356  0.534715  ...  0.540774
# face-2         0.517218  0.519985  0.527824  0.537330  ...  0.542549
# face-3         0.508275  0.512669  0.520244  0.529460  ...  0.535133
# face-4         0.511242  0.515550  0.524563  0.534917  ...  0.541114
# ...                 ...       ...       ...       ...  ...       ...
# right_hand-16  0.445551  0.401285  0.320296  0.217971  ...       NaN
# right_hand-17  0.305635  0.272736  0.233316  0.185122  ...       NaN
# right_hand-18  0.326248  0.282339  0.221445  0.150808  ...       NaN
# right_hand-19  0.352488  0.299400  0.220874  0.132357  ...       NaN
# right_hand-20  0.384617  0.322036  0.223218  0.120885  ...       NaN
#
#                      14        15        16        17        18        19  \
# face-0         0.540863  0.539631  0.538870  0.537460  0.538041  0.536197
# face-1         0.541330  0.541150  0.540376  0.539333  0.538957  0.537321
# face-2         0.543044  0.542850  0.542128  0.541073  0.540639  0.539162
# face-3         0.535540  0.535418  0.534454  0.533305  0.532867  0.531290
# face-4         0.541668  0.541508  0.540682  0.539613  0.539233  0.537561
# ...                 ...       ...       ...       ...       ...       ...
# right_hand-16       NaN       NaN       NaN       NaN       NaN       NaN
# right_hand-17       NaN       NaN       NaN       NaN       NaN       NaN
# right_hand-18       NaN       NaN       NaN       NaN       NaN       NaN
# right_hand-19       NaN       NaN       NaN       NaN       NaN       NaN
# right_hand-20       NaN       NaN       NaN       NaN       NaN       NaN
#
#                      20        21        22
# face-0         0.535788  0.535696  0.536416
# face-1         0.537178  0.535058  0.535971
# face-2         0.538990  0.537231  0.537866
# face-3         0.530816  0.528941  0.529734
# face-4         0.537360  0.535184  0.536143
# ...                 ...       ...       ...
# right_hand-16       NaN       NaN  0.001660
# right_hand-17       NaN       NaN  0.042694
# right_hand-18       NaN       NaN  0.006723
# right_hand-19       NaN       NaN -0.014755
# right_hand-20       NaN       NaN -0.031811
#
# [543 rows x 23 columns]

# %%
df[df["type"] == "pose"].sort_values("row_id")
# Out:
#        frame      row_id  type  landmark_index         x         y         z
# 489       20   20-pose-0  pose               0  0.524597  0.329134 -0.976228
# 490       20   20-pose-1  pose               1  0.566472  0.284107 -0.913417
# 499       20  20-pose-10  pose              10  0.482853  0.377581 -0.780198
# 500       20  20-pose-11  pose              11  0.830147  0.563290 -0.303732
# 501       20  20-pose-12  pose              12  0.312736  0.523624 -0.185898
# ...      ...         ...   ...             ...       ...       ...       ...
# 12440     42   42-pose-5  pose               5  0.487127  0.295725 -0.969664
# 12441     42   42-pose-6  pose               6  0.467742  0.296605 -0.969754
# 12442     42   42-pose-7  pose               7  0.664733  0.318926 -0.587208
# 12443     42   42-pose-8  pose               8  0.449085  0.320256 -0.447975
# 12444     42   42-pose-9  pose               9  0.594038  0.390422 -0.891751
#
# [759 rows x 7 columns]

# %%
df["type"].value_counts()
# Out:
# face          10764
# pose            759
# left_hand       483
# right_hand      483
# Name: type, dtype: int64

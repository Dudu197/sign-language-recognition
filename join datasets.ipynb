# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
files = [
    "lsa64_dataset.csv",
    "lsa64_dataset_part_2.csv",
    "lsa64_dataset_part_3.csv",
]

# %%
dfs = [pd.read_csv(f) for f in files]

# %%
for df in dfs:
    hand_columns = [i for i in df.columns if i.startswith("hand_")]
    face_columns = [i for i in df.columns if i.startswith("face_")]
    df["missing_hand"] = eval(" & ".join([f"(df['{h}'] == 0)" for h in hand_columns]))
    df["missing_face"] = eval(" & ".join([f"(df['{h}'] == 0)" for h in face_columns]))

# %%
categories_loss = []
for df in dfs:
    for category in df["category"].unique():
        missing = len(df[(df["category"] == category) & (df["missing_hand"] == True)])
        categories_loss.append((category, missing,))

# %%
categories_loss.sort(key=lambda i: i[1])

# %%
df_best = pd.DataFrame(columns=df.columns)
for category in categories_loss[:10]:
    df = dfs[(category[0] + 1) // 11]
    df = df[df["category"] == category[0]]
    df_best = pd.concat([df_best, df])
# Out:
# 5
# 18
# 21
# 4
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# 30
# 22
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# 2
# 26
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# 1
# 3
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33260\1193812661.py:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])

# %%
df_best
# Out:
#       Unnamed: 0 category       video_name frame  hand_0_wrist_x  \
# 23150      23150        5  005_001_001.mp4     0        0.420772
# 23151      23151        5  005_001_001.mp4     1        0.421121
# 23152      23152        5  005_001_001.mp4     2        0.420025
# 23153      23153        5  005_001_001.mp4     3        0.419329
# 23154      23154        5  005_001_001.mp4     4        0.418654
# ...          ...      ...              ...   ...             ...
# 18055      18055        3  003_010_005.mp4   113        0.425657
# 18056      18056        3  003_010_005.mp4   114        0.425624
# 18057      18057        3  003_010_005.mp4   115        0.424986
# 18058      18058        3  003_010_005.mp4   116        0.424861
# 18059      18059        3  003_010_005.mp4   117        0.423886
#
#        hand_0_wrist_y  hand_0_wrist_z  hand_0_thumb_cmc_x  hand_0_thumb_cmc_y  \
# 23150        0.550836    1.636182e-07            0.443854            0.542178
# 23151        0.563831    1.745975e-07            0.440999            0.549937
# 23152        0.567050    1.688192e-07            0.440097            0.550066
# 23153        0.569760    1.583114e-07            0.440057            0.551531
# 23154        0.571615    1.575574e-07            0.439785            0.553101
# ...               ...             ...                 ...                 ...
# 18055        0.534980    1.647184e-07            0.441462            0.565812
# 18056        0.535997    1.647716e-07            0.441336            0.566124
# 18057        0.536302    1.625014e-07            0.440926            0.566188
# 18058        0.536518    1.643235e-07            0.441036            0.566482
# 18059        0.537137    1.613287e-07            0.440315            0.566899
#
#        hand_0_thumb_cmc_z  ...  pose_left_heel_y  pose_left_heel_z  \
# 23150           -0.005283  ...          1.827304          0.441803
# 23151           -0.006402  ...          1.824616          0.554366
# 23152           -0.005739  ...          1.828198          0.650777
# 23153           -0.005438  ...          1.828721          0.657948
# 23154           -0.005162  ...          1.829020          0.602851
# ...                   ...  ...               ...               ...
# 18055           -0.010215  ...          1.912102          0.448031
# 18056           -0.009921  ...          1.911224          0.435046
# 18057           -0.009505  ...          1.911721          0.403390
# 18058           -0.009677  ...          1.910918          0.399239
# 18059           -0.009610  ...          1.910889          0.383239
#
#        pose_right_foot_index_x  pose_right_foot_index_y  \
# 23150                 0.538584                 1.896927
# 23151                 0.534780                 1.899688
# 23152                 0.546780                 1.903675
# 23153                 0.549568                 1.905399
# 23154                 0.554763                 1.906695
# ...                        ...                      ...
# 18055                 0.470084                 2.008406
# 18056                 0.468588                 2.008240
# 18057                 0.467247                 2.008238
# 18058                 0.466432                 2.007564
# 18059                 0.466071                 2.007416
#
#        pose_right_foot_index_z  pose_left_foot_index_x  \
# 23150                 0.008400                0.443128
# 23151                 0.126206                0.439994
# 23152                 0.207621                0.449782
# 23153                 0.212084                0.451675
# 23154                 0.182242                0.456765
# ...                        ...                     ...
# 18055                -0.060018                0.377270
# 18056                -0.058428                0.375483
# 18057                -0.061164                0.372336
# 18058                -0.060832                0.371874
# 18059                -0.061003                0.371401
#
#        pose_left_foot_index_y  pose_left_foot_index_z  missing_hand  \
# 23150                1.888999                0.146504         False
# 23151                1.889553                0.243100         False
# 23152                1.897125                0.322711         False
# 23153                1.900439                0.327484         False
# 23154                1.902547                0.282989         False
# ...                       ...                     ...           ...
# 18055                1.979426                0.118266         False
# 18056                1.978823                0.112068         False
# 18057                1.978815                0.085725         False
# 18058                1.977763                0.078122         False
# 18059                1.977552                0.056029         False
#
#        missing_face
# 23150         False
# 23151         False
# 23152         False
# 23153         False
# 23154         False
# ...             ...
# 18055         False
# 18056         False
# 18057         False
# 18058         False
# 18059         False
#
# [61620 rows x 1629 columns]

# %%
df_best.to_csv("lsa64_dataset_best.csv")

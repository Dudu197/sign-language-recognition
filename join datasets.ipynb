# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt

# %%
files = [
    "lsa64_dataset.csv",
    "lsa64_dataset_part_2.csv",
    "lsa64_dataset_part_3.csv",
]

# %%
path = "datasets/dot/raw/"
files = [path + i for i in os.listdir(path)]
files
# Out:
# ['datasets/dot/raw/ABIAS.csv',
#  'datasets/dot/raw/ABIATAR.csv',
#  'datasets/dot/raw/ABIÚDE.csv',
#  'datasets/dot/raw/ACAZ.csv',
#  'datasets/dot/raw/ADRAMÍTIO.csv',
#  'datasets/dot/raw/ALEXANDRE.csv',
#  'datasets/dot/raw/ALEXANDRIA.csv',
#  'datasets/dot/raw/ALIANÇA.csv',
#  'datasets/dot/raw/AMINADABE.csv',
#  'datasets/dot/raw/AMOM.csv',
#  'datasets/dot/raw/ANANIAS.csv',
#  'datasets/dot/raw/ANFÍPOLIS.csv',
#  'datasets/dot/raw/ANTIOQUIA DA PISÍDIA.csv',
#  'datasets/dot/raw/ANÁS.csv',
#  'datasets/dot/raw/APOLO.csv',
#  'datasets/dot/raw/APOLÔNIA.csv',
#  'datasets/dot/raw/AQUIM.csv',
#  'datasets/dot/raw/AREÓPAGO.csv',
#  'datasets/dot/raw/ARIMATÉIA.csv',
#  'datasets/dot/raw/ARISTARCO.csv',
#  'datasets/dot/raw/ARQUIPO.csv',
#  'datasets/dot/raw/ASA.csv',
#  'datasets/dot/raw/ASSÔS.csv',
#  'datasets/dot/raw/BARAQUIAS.csv',
#  'datasets/dot/raw/BARJESUS.csv',
#  'datasets/dot/raw/BEOR.csv',
#  'datasets/dot/raw/BETFAGÉ.csv',
#  'datasets/dot/raw/BISPOS.csv',
#  'datasets/dot/raw/BITÍNIA.csv',
#  'datasets/dot/raw/BLASTO.csv',
#  'datasets/dot/raw/BONS PORTOS.csv',
#  'datasets/dot/raw/BÁRBAROS.csv',
#  'datasets/dot/raw/CAFARNAUM.csv',
#  'datasets/dot/raw/CAIFÁS.csv',
#  'datasets/dot/raw/CALDEU.csv',
#  'datasets/dot/raw/CAMINHO.csv',
#  'datasets/dot/raw/CANÁ DA GALILEIA.csv',
#  'datasets/dot/raw/CAPADÓCIA.csv',
#  'datasets/dot/raw/CARÁTER.csv',
#  'datasets/dot/raw/CASTOR.csv',
#  'datasets/dot/raw/CAUDA.csv',
#  'datasets/dot/raw/CEDROM.csv',
#  'datasets/dot/raw/CEFAS.csv',
#  'datasets/dot/raw/CEVA.csv',
#  'datasets/dot/raw/CHEIO DO FRUTO DE JUSTIÇA.csv',
#  'datasets/dot/raw/CHIPRE.csv',
#  'datasets/dot/raw/CILÍCIA.csv',
#  'datasets/dot/raw/CIRCUNCISÃO.csv',
#  'datasets/dot/raw/CITA.csv',
#  'datasets/dot/raw/CLAUDIO.csv',
#  'datasets/dot/raw/CLEMENTE.csv',
#  'datasets/dot/raw/CLOPAS.csv',
#  'datasets/dot/raw/CNIDO.csv',
#  'datasets/dot/raw/COLOSSOS.csv',
#  'datasets/dot/raw/CONSAGRADOS.csv',
#  'datasets/dot/raw/CORAZIM.csv',
#  'datasets/dot/raw/CRENTE.csv',
#  'datasets/dot/raw/CRETA.csv',
#  'datasets/dot/raw/CRETENSES.csv',
#  'datasets/dot/raw/CRISTO.csv',
#  'datasets/dot/raw/CÓS.csv',
#  'datasets/dot/raw/DALMANUTA.csv',
#  'datasets/dot/raw/DALMÁCIA.csv',
#  'datasets/dot/raw/DAMASCO.csv',
#  'datasets/dot/raw/DANIEL.csv',
#  'datasets/dot/raw/DAVI.csv',
#  'datasets/dot/raw/DELITOS.csv',
#  'datasets/dot/raw/DEMAS.csv',
#  'datasets/dot/raw/DEMÉTRIO.csv',
#  'datasets/dot/raw/DENÁRIOS.csv',
#  'datasets/dot/raw/DERBE.csv',
#  'datasets/dot/raw/DESERTO DA JUDEIA.csv',
#  'datasets/dot/raw/DESONESTA.csv',
#  'datasets/dot/raw/DEUSES.csv',
#  'datasets/dot/raw/DIANA.csv',
#  'datasets/dot/raw/DIGNO.csv',
#  'datasets/dot/raw/DIONÍSIO.csv',
#  'datasets/dot/raw/DISCERNIMENTO.csv',
#  'datasets/dot/raw/DISCÍPULOS.csv',
#  'datasets/dot/raw/Diáconos.csv',
#  'datasets/dot/raw/DRACMAS.csv',
#  'datasets/dot/raw/DRUSILA.csv',
#  'datasets/dot/raw/DÂMARIS.csv',
#  'datasets/dot/raw/EFRAIM.csv',
#  'datasets/dot/raw/ELAMITAS.csv',
#  'datasets/dot/raw/ELIAQUIM.csv',
#  'datasets/dot/raw/ELIAS.csv',
#  'datasets/dot/raw/ELIÚDE.csv',
#  'datasets/dot/raw/EMANUEL.csv',
#  'datasets/dot/raw/ENOM.csv',
#  'datasets/dot/raw/EPAFRODITO.csv',
#  'datasets/dot/raw/EPICUREUS.csv',
#  'datasets/dot/raw/ERASTO.csv',
#  'datasets/dot/raw/ERVAS DANINHAS.csv',
#  'datasets/dot/raw/ESCOLA DE TIRANO.csv',
#  'datasets/dot/raw/ESCRIBAS.csv',
#  'datasets/dot/raw/ESPIRITUAL.csv',
#  'datasets/dot/raw/ESPÍRITO.csv',
#  'datasets/dot/raw/ESROM.csv',
#  'datasets/dot/raw/ESTRANGEIRO.csv',
#  'datasets/dot/raw/ESTÁDIOS.csv',
#  'datasets/dot/raw/ESTÉFANAS.csv',
#  'datasets/dot/raw/ESTÊVÃO.csv',
#  'datasets/dot/raw/ESTÓICOS.csv',
#  'datasets/dot/raw/ETERNO.csv',
#  'datasets/dot/raw/ETIÓPIA.csv',
#  'datasets/dot/raw/EUNICE.csv',
#  'datasets/dot/raw/EUNUCO.csv',
#  'datasets/dot/raw/EVA.csv',
#  'datasets/dot/raw/EVANGELHO.csv',
#  'datasets/dot/raw/EVANGELISTA.csv',
#  'datasets/dot/raw/EVÓDIA.csv',
#  'datasets/dot/raw/EZEQUIAS.csv',
#  'datasets/dot/raw/FENICE.csv',
#  'datasets/dot/raw/FESTA DA DEDICAÇÃO.csv',
#  'datasets/dot/raw/FESTA JUDAICA DOS TABERNÁCULOS.csv',
#  'datasets/dot/raw/FIGUEIRA.csv',
#  'datasets/dot/raw/FILACTÉRIOS.csv',
#  'datasets/dot/raw/FILETO.csv',
#  'datasets/dot/raw/FILHO DA PERDIÇÃO.csv',
#  'datasets/dot/raw/FILHO DO HOMEM.csv',
#  'datasets/dot/raw/FILHOS DE DAVI.csv',
#  'datasets/dot/raw/FILIPE.csv',
#  'datasets/dot/raw/FILIPENSES.csv',
#  'datasets/dot/raw/FILIPOS.csv',
#  'datasets/dot/raw/FONTE DE ÁGUA.csv',
#  'datasets/dot/raw/FORMOSA.csv',
#  'datasets/dot/raw/FRUTO DO ESPÍRITO.csv',
#  'datasets/dot/raw/FRUTOS DO ARREPENDIMENTO.csv',
#  'datasets/dot/raw/FRÍGIA.csv',
#  'datasets/dot/raw/FÉ.csv',
#  'datasets/dot/raw/FÉLIX.csv',
#  'datasets/dot/raw/FÍGELO.csv',
#  'datasets/dot/raw/GADARENOS.csv',
#  'datasets/dot/raw/Gaio.csv',
#  'datasets/dot/raw/GALILEIA.csv',
#  'datasets/dot/raw/GALILEUS.csv',
#  'datasets/dot/raw/GALÁCIA.csv',
#  'datasets/dot/raw/GAZA.csv',
#  'datasets/dot/raw/GENEALOGIA.csv',
#  'datasets/dot/raw/GENTIOS.csv',
#  'datasets/dot/raw/GETSÊMANI.csv',
#  'datasets/dot/raw/GLORIFICADO.csv',
#  'datasets/dot/raw/GLORIOSO.csv',
#  'datasets/dot/raw/GRAÇA.csv',
#  'datasets/dot/raw/HAMOR.csv',
#  'datasets/dot/raw/HARÃ.csv',
#  'datasets/dot/raw/HEBREU.csv',
#  'datasets/dot/raw/HELENISTAS.csv',
#  'datasets/dot/raw/HERANÇA.csv',
#  'datasets/dot/raw/HERDEIRO.csv',
#  'datasets/dot/raw/HERESIA.csv',
#  'datasets/dot/raw/HERMOM.csv',
#  'datasets/dot/raw/HERMÓGENES.csv',
#  'datasets/dot/raw/HERODES ANTIPAS.csv',
#  'datasets/dot/raw/HERODES FILIPE I.csv',
#  'datasets/dot/raw/HIERÁPOLIS.csv',
#  'datasets/dot/raw/HIMENEU.csv',
#  'datasets/dot/raw/HIPOCRISIA.csv',
#  'datasets/dot/raw/HIPÓCRITAS.csv',
#  'datasets/dot/raw/HOMOSSEXUAIS.csv',
#  'datasets/dot/raw/HONRÁVEL.csv',
#  'datasets/dot/raw/HORA SEXTA.csv',
#  'datasets/dot/raw/HOSANA.csv',
#  'datasets/dot/raw/HOSPITALEIRO.csv',
#  'datasets/dot/raw/HOSTES DO CÉU.csv',
#  'datasets/dot/raw/ICÔNIO.csv',
#  'datasets/dot/raw/IDÓLATRA.csv',
#  'datasets/dot/raw/IGNORÂNCIA.csv',
#  'datasets/dot/raw/IGREJA.csv',
#  'datasets/dot/raw/IGREJAS.csv',
#  'datasets/dot/raw/IMAGEM DE DEUS.csv',
#  'datasets/dot/raw/IMENSURÁVEL.csv',
#  'datasets/dot/raw/IMITADORES.csv',
#  'datasets/dot/raw/IMORALIDADE SEXUAL.csv',
#  'datasets/dot/raw/IMORTAL.csv',
#  'datasets/dot/raw/IMPARCIALIDADE.csv',
#  'datasets/dot/raw/IMPERADOR.csv',
#  'datasets/dot/raw/IMPOSTOS.csv',
#  'datasets/dot/raw/INCIRCUNCISÃO.csv',
#  'datasets/dot/raw/INCREDULIDADE.csv',
#  'datasets/dot/raw/INCRÉDULOS.csv',
#  'datasets/dot/raw/INCUMBIDO.csv',
#  'datasets/dot/raw/INFAMATÓRIO.csv',
#  'datasets/dot/raw/INFERNO.csv',
#  'datasets/dot/raw/INFRUTÍFEROS.csv',
#  'datasets/dot/raw/INIQUIDADE.csv',
#  'datasets/dot/raw/INJUSTIÇA.csv',
#  'datasets/dot/raw/INOCENTES.csv',
#  'datasets/dot/raw/INSENSATO.csv',
#  'datasets/dot/raw/INSTRUÍDO.csv',
#  'datasets/dot/raw/INSUBORDINADO.csv',
#  'datasets/dot/raw/INTERCESSORES.csv',
#  'datasets/dot/raw/INTIMIDADOS.csv',
#  'datasets/dot/raw/IRREPREENSÍVEL.csv',
#  'datasets/dot/raw/ISAQUE.csv',
#  'datasets/dot/raw/ISAÍAS.csv',
#  'datasets/dot/raw/ISRAEL.csv',
#  'datasets/dot/raw/ITÁLIA.csv',
#  'datasets/dot/raw/JACÓ ( PAI DE JOSÉ).csv',
#  'datasets/dot/raw/JACÓ.csv',
#  'datasets/dot/raw/JAEL.csv',
#  'datasets/dot/raw/JAMBRES.csv',
#  'datasets/dot/raw/JANES.csv',
#  'datasets/dot/raw/JASON.csv',
#  'datasets/dot/raw/JECONIAS.csv',
#  'datasets/dot/raw/JEJUAR.csv',
#  'datasets/dot/raw/JERICÓ.csv',
#  'datasets/dot/raw/JERUSALÉM.csv',
#  'datasets/dot/raw/JESSÉ.csv',
#  'datasets/dot/raw/JESUS CRISTO.csv',
#  'datasets/dot/raw/JESUS JUSTO.csv',
#  'datasets/dot/raw/JESUS.csv',
#  'datasets/dot/raw/JETRO.csv',
#  'datasets/dot/raw/JEZABEL.csv',
#  'datasets/dot/raw/JOPE.csv',
#  'datasets/dot/raw/JORDÃO.csv',
#  'datasets/dot/raw/JORÃO.csv',
#  'datasets/dot/raw/JOSAFÁ.csv',
#  'datasets/dot/raw/JOSIAS.csv',
#  'datasets/dot/raw/JOSÉ  (PAI DE JESUS ).csv',
#  'datasets/dot/raw/JOSÉ (irmão de Jesus).csv',
#  'datasets/dot/raw/JOSÉ BARSABÁS.csv',
#  'datasets/dot/raw/JOSÉ DE ARIMATEIA.csv',
#  'datasets/dot/raw/JOSÉ.csv',
#  'datasets/dot/raw/JOTÃO.csv',
#  'datasets/dot/raw/JOÃO BATISTA.csv',
#  'datasets/dot/raw/JOÃO.csv',
#  'datasets/dot/raw/JUDAS (NÃO O ISCARIOTES ).csv',
#  'datasets/dot/raw/JUDAS BARSABAS.csv',
#  'datasets/dot/raw/JUDAS DA GALILÉIA.csv',
#  'datasets/dot/raw/JUDAS DAMASCENO.csv',
#  'datasets/dot/raw/JUDAS IRMÃO DE JESUS.csv',
#  'datasets/dot/raw/JUDEIA.csv',
#  'datasets/dot/raw/JUDEUS.csv',
#  'datasets/dot/raw/JUDÁ.csv',
#  'datasets/dot/raw/JÓ.csv',
#  'datasets/dot/raw/JÔNATAS.csv',
#  'datasets/dot/raw/LAODICEIA.csv',
#  'datasets/dot/raw/LASEIA.csv',
#  'datasets/dot/raw/LEME.csv',
#  'datasets/dot/raw/LEPRA.csv',
#  'datasets/dot/raw/LEVITAS.csv',
#  'datasets/dot/raw/LIBERTINAGEM.csv',
#  'datasets/dot/raw/LIDA.csv',
#  'datasets/dot/raw/LINO.csv',
#  'datasets/dot/raw/LISTRA.csv',
#  'datasets/dot/raw/LOIDE.csv',
#  'datasets/dot/raw/LONGANIMIDADE.csv',
#  'datasets/dot/raw/LOUVOR.csv',
#  'datasets/dot/raw/LUA NOVA.csv',
#  'datasets/dot/raw/LUCAS.csv',
#  'datasets/dot/raw/LÁZARO.csv',
#  'datasets/dot/raw/LÍCIA.csv',
#  'datasets/dot/raw/LÍDIA.csv',
#  'datasets/dot/raw/LÍNGUA DOS HEBREUS.csv',
#  'datasets/dot/raw/LÍNGUA MATERNA.csv',
#  'datasets/dot/raw/LÓ.csv',
#  'datasets/dot/raw/MACEDÔNIA.csv',
#  'datasets/dot/raw/MALCO.csv',
#  'datasets/dot/raw/MALTA.csv',
#  'datasets/dot/raw/MANASSÉS.csv',
#  'datasets/dot/raw/MANAÉM.csv',
#  'datasets/dot/raw/MANTO PÚRPURA.csv',
#  'datasets/dot/raw/MANÁ.csv',
#  'datasets/dot/raw/MAR ADRIÁTICO.csv',
#  'datasets/dot/raw/MAR DA GALILEIA.csv',
#  'datasets/dot/raw/MAR VERMELHO.csv',
#  'datasets/dot/raw/MARIA ESPOSA DE CLOPAS.csv',
#  'datasets/dot/raw/MARIA IRMÃ DE LÁZARO.csv',
#  'datasets/dot/raw/MARIA MADALENA.csv',
#  'datasets/dot/raw/MARIA MÃE DE JESUS.csv',
#  'datasets/dot/raw/MARTA.csv',
#  'datasets/dot/raw/MATEUS.csv',
#  'datasets/dot/raw/MATIAS.csv',
#  'datasets/dot/raw/MEDIADOR.csv',
#  'datasets/dot/raw/MEDOS.csv',
#  'datasets/dot/raw/MELQUISEDEQUE.csv',
#  'datasets/dot/raw/MEMBROS DO CONSELHO.csv',
#  'datasets/dot/raw/MENSAGEIRO.csv',
#  'datasets/dot/raw/MERCADO.csv',
#  'datasets/dot/raw/MESOPOTÂMIA.csv',
#  'datasets/dot/raw/MESSIAS.csv',
#  'datasets/dot/raw/MESTRE DO POVO.csv',
#  'datasets/dot/raw/MIDIÃ.csv',
#  'datasets/dot/raw/MILAGRES.csv',
#  'datasets/dot/raw/MILETO.csv',
#  'datasets/dot/raw/MINISTRO.csv',
#  'datasets/dot/raw/MINISTÉRIO.csv',
#  'datasets/dot/raw/MIRRA.csv',
#  'datasets/dot/raw/MISERICÓRDIA.csv',
#  'datasets/dot/raw/MITILENE.csv',
#  'datasets/dot/raw/MITOS JUDAICOS.csv',
#  'datasets/dot/raw/MITOS.csv',
#  'datasets/dot/raw/MODERADOS.csv',
#  'datasets/dot/raw/MOLOQUE.csv',
#  'datasets/dot/raw/MONTE DAS OLIVEIRAS.csv',
#  'datasets/dot/raw/MONTE SIÃO.csv',
#  'datasets/dot/raw/MORTE DE CRUZ.csv',
#  'datasets/dot/raw/MOSTARDA.csv',
#  'datasets/dot/raw/MULTIFORME.csv',
#  'datasets/dot/raw/MULTILAÇÃO.csv',
#  'datasets/dot/raw/MÍSIA.csv',
#  'datasets/dot/raw/NASCER DA CARNE.csv',
#  'datasets/dot/raw/NASCER DA ÁGUA.csv',
#  'datasets/dot/raw/NASCER DO ESPÍRITO.csv',
#  'datasets/dot/raw/NASOM.csv',
#  'datasets/dot/raw/NATANAEL.csv',
#  'datasets/dot/raw/NATUREZA.csv',
#  'datasets/dot/raw/NAZARENO.csv',
#  'datasets/dot/raw/NAZARÉ.csv',
#  'datasets/dot/raw/NICANOR.csv',
#  'datasets/dot/raw/NICODEMOS.csv',
#  'datasets/dot/raw/NICOLAU.csv',
#  'datasets/dot/raw/NINFA.csv',
#  'datasets/dot/raw/NORA.csv',
#  'datasets/dot/raw/NOVO CONVERTIDO.csv',
#  'datasets/dot/raw/NOVO HOMEM.csv',
#  'datasets/dot/raw/NOVO NASCIMENTO.csv',
#  'datasets/dot/raw/NOÉ.csv',
#  'datasets/dot/raw/OBEDE.csv',
#  'datasets/dot/raw/OBREIRO.csv',
#  'datasets/dot/raw/OBSENIDADES.csv',
#  'datasets/dot/raw/OFERTA DE SACRIFÍCIO.csv',
#  'datasets/dot/raw/OFICIAIS.csv',
#  'datasets/dot/raw/ONESÍFORO.csv',
#  'datasets/dot/raw/ONÉSIMO.csv',
#  'datasets/dot/raw/ORIENTE.csv',
#  'datasets/dot/raw/OUSADIA.csv',
#  'datasets/dot/raw/OUVISTES E VISTES EM MIM.csv',
#  'datasets/dot/raw/PAFOS.csv',
#  'datasets/dot/raw/PAI CELESTIAL.csv',
#  'datasets/dot/raw/PAIXÕES MUNDANAS.csv',
#  'datasets/dot/raw/PALAVRA DA VIDA.csv',
#  'datasets/dot/raw/PALAVRA DE DEUS.csv',
#  'datasets/dot/raw/PALAVRA.csv',
#  'datasets/dot/raw/PALAVRAS OBCENAS.csv',
#  'datasets/dot/raw/PALAVRAS PERSUASIVAS.csv',
#  'datasets/dot/raw/PANFÍLIA.csv',
#  'datasets/dot/raw/PASTOR.csv',
#  'datasets/dot/raw/PATRIARCA.csv',
#  'datasets/dot/raw/PAULO.csv',
#  'datasets/dot/raw/PAVIMENTO DE PEDRA GABATÁ.csv',
#  'datasets/dot/raw/PECADOS.csv',
#  'datasets/dot/raw/PEDRA DE ESQUINA.csv',
#  'datasets/dot/raw/PEDRA DE TROPEÇO.csv',
#  'datasets/dot/raw/PEDRO.csv',
#  'datasets/dot/raw/PENTECOSTE.csv',
#  'datasets/dot/raw/PERDA.csv',
#  'datasets/dot/raw/PEREGRINOS.csv',
#  'datasets/dot/raw/PERGAMINHOS.csv',
#  'datasets/dot/raw/PERGE.csv',
#  'datasets/dot/raw/PERMANECER.csv',
#  'datasets/dot/raw/PERSEVERANÇA.csv',
#  'datasets/dot/raw/PESCADORES DE HOMENS.csv',
#  'datasets/dot/raw/PLENA.csv',
#  'datasets/dot/raw/PLENITUDE DO TEMPO.csv',
#  'datasets/dot/raw/PONTO.csv',
#  'datasets/dot/raw/POTESTADES.csv',
#  'datasets/dot/raw/POVOADO.csv',
#  'datasets/dot/raw/PREDESTINAR.csv',
#  'datasets/dot/raw/PRESBÍTEROS.csv',
#  'datasets/dot/raw/PRESCIÊNCIA.csv',
#  'datasets/dot/raw/PRETÓRIO.csv',
#  'datasets/dot/raw/PRINCIPADOS.csv',
#  'datasets/dot/raw/PRINCIPAIS SACERDOTES.csv',
#  'datasets/dot/raw/PRISCILA.csv',
#  'datasets/dot/raw/PRISIONEIRO NO SENHOR.csv',
#  'datasets/dot/raw/PROA.csv',
#  'datasets/dot/raw/PROCLAMAR.csv',
#  'datasets/dot/raw/PRODÍGIO.csv',
#  'datasets/dot/raw/PROFANO.csv',
#  'datasets/dot/raw/PROFETA JOEL.csv',
#  'datasets/dot/raw/PROFETA.csv',
#  'datasets/dot/raw/PROFUNDEZAS DA TERRA.csv',
#  'datasets/dot/raw/PROPRIEDADE.csv',
#  'datasets/dot/raw/PROPRIETÁRIO DE TERRAS.csv',
#  'datasets/dot/raw/PROPÓSITO.csv',
#  'datasets/dot/raw/PROSTRAR.csv',
#  'datasets/dot/raw/PROSÉLITO.csv',
#  'datasets/dot/raw/PROVISÃO.csv',
#  'datasets/dot/raw/PRUDENTE.csv',
#  'datasets/dot/raw/PTOLEMAIDA.csv',
#  'datasets/dot/raw/PUTÉOLI.csv',
#  'datasets/dot/raw/PÁRMENAS.csv',
#  'datasets/dot/raw/PÁTARA.csv',
#  'datasets/dot/raw/PÃES ASMOS.csv',
#  'datasets/dot/raw/PÃES SEM FERMENTO.csv',
#  'datasets/dot/raw/PÃO DE CEVADA.csv',
#  'datasets/dot/raw/PÓRTICO DE SALOMÃO.csv',
#  'datasets/dot/raw/PÔNCIO PILATOS.csv',
#  'datasets/dot/raw/RAABE.csv',
#  'datasets/dot/raw/RABI.csv',
#  'datasets/dot/raw/RABONI (MESTRE).csv',
#  'datasets/dot/raw/RAMO.csv',
#  'datasets/dot/raw/RAMOS DE PALMEIRAS.csv',
#  'datasets/dot/raw/RAMÁ.csv',
#  'datasets/dot/raw/RANGER DE DENTES.csv',
#  'datasets/dot/raw/RAQUEL.csv',
#  'datasets/dot/raw/RAÇA DE VIBORAS.csv',
#  'datasets/dot/raw/REBELDES.csv',
#  'datasets/dot/raw/RECONCILIAR.csv',
#  'datasets/dot/raw/REFUTAR.csv',
#  'datasets/dot/raw/REFÃ.csv',
#  'datasets/dot/raw/REGENERAR.csv',
#  'datasets/dot/raw/REGIÃO.csv',
#  'datasets/dot/raw/REI DOS JUDEUS.csv',
#  'datasets/dot/raw/REI HERODES.csv',
#  'datasets/dot/raw/REINO DE DEUS.csv',
#  'datasets/dot/raw/REINO DOS CÉUS.csv',
#  'datasets/dot/raw/REINO.csv',
#  'datasets/dot/raw/REPREENDER.csv',
#  'datasets/dot/raw/REPUDIAR.csv',
#  'datasets/dot/raw/RESSURREIÇÃO DOS MORTOS.csv',
#  'datasets/dot/raw/RESSURREIÇÃO.csv',
#  'datasets/dot/raw/REVELAÇÕES.csv',
#  'datasets/dot/raw/REVERENTE.csv',
#  'datasets/dot/raw/RICO.csv',
#  'datasets/dot/raw/RIGOR.csv',
#  'datasets/dot/raw/RIQUEZAS.csv',
#  'datasets/dot/raw/ROBOÃO.csv',
#  'datasets/dot/raw/RODES.csv',
#  'datasets/dot/raw/ROMA.csv',
#  'datasets/dot/raw/ROMANOS.csv',
#  'datasets/dot/raw/ROUPA DE SACO.csv',
#  'datasets/dot/raw/RUA DIREITA.csv',
#  'datasets/dot/raw/RUDIMENTOS DO MUNDO.csv',
#  'datasets/dot/raw/RUÍNA.csv',
#  'datasets/dot/raw/RÉGIO.csv',
#  'datasets/dot/raw/SADIOS NA FÉ.csv',
#  'datasets/dot/raw/SADOQUE.csv',
#  'datasets/dot/raw/SALAMINA.csv',
#  'datasets/dot/raw/SALATIEL.csv',
#  'datasets/dot/raw/SALMOM.csv',
#  'datasets/dot/raw/SALMONA.csv',
#  'datasets/dot/raw/SALVADOR.csv',
#  'datasets/dot/raw/SAMOTRÁCIA.csv',
#  'datasets/dot/raw/SANTOS.csv',
#  'datasets/dot/raw/SEITA.csv',
#  'datasets/dot/raw/SELADO.csv',
#  'datasets/dot/raw/SELÊUCIA.csv',
#  'datasets/dot/raw/SENSUALIDADE.csv',
#  'datasets/dot/raw/SERVO.csv',
#  'datasets/dot/raw/SEU AGRADO.csv',
#  'datasets/dot/raw/SICAR.csv',
#  'datasets/dot/raw/SIMÃO BARJONAS.csv',
#  'datasets/dot/raw/SIMÃO DE CIRENE.csv',
#  'datasets/dot/raw/SIMÃO LEPROSO.csv',
#  'datasets/dot/raw/SIMÃO.csv',
#  'datasets/dot/raw/SINAIS E MARAVILHAS.csv',
#  'datasets/dot/raw/SIQUÉM.csv',
#  'datasets/dot/raw/SIRACUSA.csv',
#  'datasets/dot/raw/SODOMA E GOMORRA.csv',
#  'datasets/dot/raw/SÉCULOS DOS SÉCULOS.csv',
#  'datasets/dot/raw/SÉRGIO PAULO.csv',
#  'datasets/dot/raw/TARSO.csv',
#  'datasets/dot/raw/TEMOR.csv',
#  'datasets/dot/raw/TEÓFILO.csv',
#  'datasets/dot/raw/TIATIRA.csv',
#  'datasets/dot/raw/TIMEU.csv',
#  'datasets/dot/raw/TITO.csv',
#  'datasets/dot/raw/TRABALHAR EM VÃO.csv',
#  'datasets/dot/raw/TRÊS VENDAS.csv',
#  'datasets/dot/raw/TÉRTULO.csv',
#  'datasets/dot/raw/TÍQUICO.csv',
#  'datasets/dot/raw/UM SÓ ESPÍRITO.csv',
#  'datasets/dot/raw/UMA SÓ ALMA.csv',
#  'datasets/dot/raw/VANGLÓRIA.csv',
#  'datasets/dot/raw/VELHO HOMEM.csv',
#  'datasets/dot/raw/ÁGABO.csv',
#  'datasets/dot/raw/ÁPIO.csv',
#  'datasets/dot/raw/ÉDEN.csv',
#  'datasets/dot/raw/ÉFESO.csv',
#  'datasets/dot/raw/ÊUBULO.csv',
#  'datasets/dot/raw/ÍMPIO.csv']

# %%
dfs = [pd.read_csv(f) for f in files]

# %%
for df in dfs:
    hand_columns = [i for i in df.columns if i.startswith("hand_")]
    face_columns = [i for i in df.columns if i.startswith("face_")]
    df["missing_hand"] = eval(" & ".join([f"(df['{h}'] == 0)" for h in hand_columns]))
    df["missing_face"] = eval(" & ".join([f"(df['{h}'] == 0)" for h in face_columns]))

# %%
categories_loss = []
for df in dfs:
    for category in df["category"].unique():
        missing = len(df[(df["category"] == category) & (df["missing_hand"] == True)])
        categories_loss.append((category, missing,))

# %%
categories_loss.sort(key=lambda i: i[1])

# %%
df_best = pd.DataFrame(columns=df.columns)
for category in categories_loss: #[:10]:
    df = dfs[(category[0] + 1) // 11]
    df = df[df["category"] == category[0]]
    df_best = pd.concat([df_best, df])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 df_best = pd.DataFrame(columns=df.columns)
#       2 for category in categories_loss: #[:10]:
# ----> 3     df = dfs[(category[0] + 1) // 11]
#       4     df = df[df["category"] == category[0]]
#       5     df_best = pd.concat([df_best, df])
#
# TypeError: can only concatenate str (not "int") to str

# %%
# All Datasets
df_best = pd.DataFrame(columns=df.columns)
for df in dfs:
    df_best = pd.concat([df_best, df])
# Out:
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])
# C:\Users\duduu\AppData\Local\Temp\ipykernel_33576\620853408.py:4: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_best = pd.concat([df_best, df])

# %%
df_best
# Out:
#    Unnamed: 0 category video_name frame  hand_0_wrist_x  hand_0_wrist_y  \
# 0           0    ABIAS  ABIAS.mp4     0        0.430396        0.788411
# 1           1    ABIAS  ABIAS.mp4     1        0.431362        0.784486
# 2           2    ABIAS  ABIAS.mp4     2        0.431172        0.785288
# 3           3    ABIAS  ABIAS.mp4     3        0.431301        0.785288
# 4           4    ABIAS  ABIAS.mp4     4        0.431106        0.785692
# ..        ...      ...        ...   ...             ...             ...
# 53         53    ÍMPIO  ÍMPIO.mp4    53        0.441903        0.956805
# 54         54    ÍMPIO  ÍMPIO.mp4    54        0.442107        0.957296
# 55         55    ÍMPIO  ÍMPIO.mp4    55        0.442280        0.959497
# 56         56    ÍMPIO  ÍMPIO.mp4    56        0.442629        0.959932
# 57         57    ÍMPIO  ÍMPIO.mp4    57        0.442266        0.960661
#
#     hand_0_wrist_z  hand_0_thumb_cmc_x  hand_0_thumb_cmc_y  \
# 0    -8.923800e-09            0.460859            0.792772
# 1    -7.673450e-08            0.461214            0.790153
# 2    -8.674111e-08            0.461018            0.790359
# 3    -8.351535e-08            0.460570            0.791003
# 4    -7.949866e-08            0.460437            0.791008
# ..             ...                 ...                 ...
# 53   -5.991478e-08            0.464679            0.932831
# 54   -5.814757e-08            0.465472            0.933835
# 55   -5.925997e-08            0.466375            0.936937
# 56   -5.973948e-08            0.466150            0.936607
# 57   -6.303348e-08            0.466352            0.937986
#
#     hand_0_thumb_cmc_z  ...  pose_left_heel_y  pose_left_heel_z  \
# 0             0.007131  ...          1.752989          0.411069
# 1             0.002917  ...          1.772637          0.430309
# 2             0.002963  ...          1.784413          0.433769
# 3             0.002512  ...          1.787939          0.432169
# 4             0.002545  ...          1.789766          0.431242
# ..                 ...  ...               ...               ...
# 53            0.000674  ...          1.906485          0.421061
# 54            0.000572  ...          1.908798          0.420009
# 55            0.000151  ...          1.911197          0.419626
# 56            0.000273  ...          1.913702          0.418142
# 57            0.000241  ...          1.915099          0.419647
#
#     pose_right_foot_index_x  pose_right_foot_index_y  pose_right_foot_index_z  \
# 0                  0.526476                 1.825754                 0.226886
# 1                  0.526694                 1.842400                 0.244059
# 2                  0.526341                 1.852564                 0.257562
# 3                  0.526402                 1.856788                 0.259625
# 4                  0.526376                 1.859626                 0.259142
# ..                      ...                      ...                      ...
# 53                 0.542296                 1.991284                 0.244417
# 54                 0.542383                 1.993512                 0.241876
# 55                 0.542512                 1.995653                 0.240244
# 56                 0.542762                 1.997770                 0.239116
# 57                 0.543118                 1.998833                 0.239118
#
#     pose_left_foot_index_x  pose_left_foot_index_y  pose_left_foot_index_z  \
# 0                 0.436790                1.826269                0.116103
# 1                 0.436220                1.848742                0.125846
# 2                 0.433511                1.860878                0.128302
# 3                 0.433235                1.864486                0.127573
# 4                 0.432713                1.866900                0.127432
# ..                     ...                     ...                     ...
# 53                0.449707                1.991373                0.106184
# 54                0.449734                1.994246                0.103601
# 55                0.450181                1.997084                0.102244
# 56                0.450670                1.999541                0.101176
# 57                0.451246                2.000709                0.101693
#
#     missing_hand  missing_face
# 0          False         False
# 1          False         False
# 2          False         False
# 3          False         False
# 4          False         False
# ..           ...           ...
# 53         False         False
# 54         False         False
# 55         False         False
# 56         False         False
# 57         False         False
#
# [168422 rows x 1629 columns]

# %%
len(df_best)
# Out:
# 168422

# %%
len(df_best[df_best["missing_hand"] == True])
# Out:
# 2308

# %%
len(df_best[df_best["missing_hand"] == True]) / len(df_best)
# Out:
# 0.013703672916839842

# %%
len(df_best[df_best["missing_face"] == True])
# Out:
# 2258

# %%
len(df_best[df_best["missing_face"] == True]) / len(df_best)
# Out:
# 0.013406799586752324

# %%
df_best.drop("Unnamed: 0", axis=1).to_csv("datasets/dot/dot_mediapipe.csv")

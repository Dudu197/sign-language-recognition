# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import json

# %%
df = pd.read_csv("../dataset_output/libras_minds/libras_minds_openpose.csv")
dataset_name = "MINDS-Libras"

# %%
df = pd.read_csv("../dataset_output/libras_ufop/libras_ufop_openpose.csv")
dataset_name = "LIBRAS-UFOP"

# %%
df
# Out:
#         category   video_name  frame  hand_0_0_x  hand_0_0_y  hand_0_0_z  \
# 0              1   p1_c1_s1_0      0    0.555807    0.567531    0.394245
# 1              1   p1_c1_s1_0      1    0.555086    0.561309    0.396433
# 2              1   p1_c1_s1_0      2    0.552441    0.554763    0.376937
# 3              1   p1_c1_s1_0      3    0.540484    0.558278    0.014662
# 4              1   p1_c1_s1_0      4    0.539812    0.537244    0.100900
# ...          ...          ...    ...         ...         ...         ...
# 202484        47  p5_c4_s9_10     36    0.511064    0.446786    0.026157
# 202485        47  p5_c4_s9_10     37    0.539804    0.431748    0.028773
# 202486        47  p5_c4_s9_10     38    0.542277    0.441707    0.030453
# 202487        47  p5_c4_s9_10     39    0.540754    0.450658    0.036463
# 202488        47  p5_c4_s9_10     40    0.522440    0.436927    0.275950
#
#         hand_0_1_x  hand_0_1_y  hand_0_1_z  hand_0_2_x  ...  pose_22_z  \
# 0         0.549136    0.575092    0.414851    0.543798  ...   0.753184
# 1         0.547985    0.570326    0.402954    0.542236  ...   0.751818
# 2         0.544950    0.563844    0.328017    0.539501  ...   0.721404
# 3         0.539830    0.565252    0.043459    0.532311  ...   0.745815
# 4         0.534094    0.548904    0.083215    0.531067  ...   0.697552
# ...            ...         ...         ...         ...  ...        ...
# 202484    0.538449    0.420391    0.030119    0.526901  ...   0.752672
# 202485    0.541779    0.429114    0.030089    0.534208  ...   0.725757
# 202486    0.542592    0.434997    0.080483    0.521517  ...   0.722870
# 202487    0.534091    0.436443    0.065288    0.541753  ...   0.716687
# 202488    0.533989    0.446403    0.045277    0.532805  ...   0.705954
#
#         pose_23_x  pose_23_y  pose_23_z  pose_24_x  pose_24_y  pose_24_z  \
# 0        0.433065   0.966341   0.781661   0.449489   0.928342   0.651774
# 1        0.433051   0.966384   0.792620   0.449503   0.930953   0.673173
# 2        0.431155   0.966412   0.771990   0.449501   0.928337   0.667928
# 3        0.433046   0.966367   0.777363   0.449523   0.928312   0.661847
# 4        0.433064   0.966390   0.749232   0.449475   0.930948   0.649300
# ...           ...        ...        ...        ...        ...        ...
# 202484   0.424943   0.955436   0.677236   0.439216   0.898344   0.543393
# 202485   0.424950   0.950097   0.681652   0.437225   0.901135   0.545763
# 202486   0.426986   0.952731   0.657443   0.435220   0.898388   0.555769
# 202487   0.424990   0.952775   0.658890   0.437217   0.901061   0.537380
# 202488   0.426990   0.950059   0.665721   0.437205   0.898362   0.538676
#
#         missing_hand  missing_face  person
# 0              False         False     1.0
# 1              False         False     1.0
# 2              False         False     1.0
# 3              False         False     1.0
# 4              False         False     1.0
# ...              ...           ...     ...
# 202484         False         False     5.0
# 202485         False         False     5.0
# 202486         False         False     5.0
# 202487         False         False     5.0
# 202488         False         False     5.0
#
# [202489 rows x 417 columns]

# %%
df_0 = df[df["frame"] == 1]

# %%
df_0["category"].value_counts().sort_index().plot(kind="bar")
plt.title(f"Category count for {dataset_name} dataset")
plt.ylabel("Count")
plt.xlabel("Sign")
plt.xticks(np.arange(1, 58, 5))
# Out:
# ([<matplotlib.axis.XTick at 0x7f586d3a5c40>,
#   <matplotlib.axis.XTick at 0x7f586d3a5c10>,
#   <matplotlib.axis.XTick at 0x7f586d378fa0>,
#   <matplotlib.axis.XTick at 0x7f586d07f910>,
#   <matplotlib.axis.XTick at 0x7f586d08a400>,
#   <matplotlib.axis.XTick at 0x7f586d08aeb0>,
#   <matplotlib.axis.XTick at 0x7f586d09c9a0>,
#   <matplotlib.axis.XTick at 0x7f586d07f3d0>,
#   <matplotlib.axis.XTick at 0x7f586d3a5700>,
#   <matplotlib.axis.XTick at 0x7f586bae2bb0>,
#   <matplotlib.axis.XTick at 0x7f586d0714c0>,
#   <matplotlib.axis.XTick at 0x7f586d071f70>],
#  [Text(1, 0, '2'),
#   Text(6, 0, '7'),
#   Text(11, 0, '12'),
#   Text(16, 0, '17'),
#   Text(21, 0, '23'),
#   Text(26, 0, '28'),
#   Text(31, 0, '33'),
#   Text(36, 0, '38'),
#   Text(41, 0, '43'),
#   Text(46, 0, '48'),
#   Text(51, 0, '53'),
#   Text(56, 0, '')])

# %%
df[["video_name", "frame"]].groupby("video_name").max().describe()
# plt.title(f"Category count for {dataset_name} dataset")
# plt.ylabel("Count")
# plt.xlabel("Sign")
# Out:
#              frame
# count  1158.000000
# mean    138.411917
# std      26.608733
# min      70.000000
# 25%     120.000000
# 50%     137.000000
# 75%     155.000000
# max     232.000000

# %%
count = df_0[["person", "category", "frame"]].groupby(["person", "category"]).count()
print("Min:", count.min())
print("Max:", count.max())
# Out:
# Min: frame    8
# dtype: int64
# Max: frame    16
# dtype: int64

# %%
with open("../openpose_benchmark.json", "r") as f:
    openpose_benchmark = json.load(f)

# %%
duration_per_frame = [(i["duration"] * 1000) / i["frames"] for i in openpose_benchmark]

# %%
print("Mean frame extraction time:", sum(duration_per_frame) / len(duration_per_frame), "ms")
print("Std:", np.std(duration_per_frame))
# Out:
# Mean frame extraction time: 291.059832813444 ms
# Std: 26.25490746999148

# %%
291 * 10
# Out:
# 2910

# %%
durations = [i["duration"] for i in openpose_benchmark]
print("Mean video extraction time:", sum(durations) / len(durations), "s")
print("Std:", np.std(durations))
# Out:
# Mean video extraction time: 36.367036922772726 s
# Std: 6.761373540555386

# %%
36.367036922772726 * 1000
# Out:
# 36367.03692277273

# %%
data = {
    100: 0.91590,
    120: 0.92955,
    140: 0.91313,
    160: 0.91094,
}

# %%
data
# Out:
# {100: 91.59, 120: 92.955, 140: 91.313, 160: 91.094}

# %%
your_bins=4
arr=plt.hist(data,bins=your_bins)
for i in range(your_bins):
    plt.text(arr[1][i],arr[0][i],str(arr[0][i]))

# %%
frames = [80, 100, 120, 138, 140, 160]
values = [0.87653, 0.91590, 0.92955, 0.91711, 0.91313, 0.91094]

# %%
fig, ax = plt.subplots()
bars = ax.plot(frames, values)
ax.scatter([frames[3]], [values[3]], color="red", s=100)
ax.scatter(frames, values)
ax.grid(axis='y')
fig.set_dpi(200)

plt.xlabel("Target Frame Count")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
fig, ax = plt.subplots()
bars = ax.bar(frames, values, width=10)
fig.set_dpi(200)

ax.bar_label(bars)
plt.title("Accuracies for frame uniformization")
plt.xlabel("Number of frames per video")
plt.ylabel("Accuracy on Test Dataset")
# Out:
# Text(0, 0.5, 'Accuracy on Test Dataset')

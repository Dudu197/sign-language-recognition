# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")

# %%
df = pd.read_csv("minds_test_dataset.csv")

# %%
df = pd.read_csv("lsa64_dataset.csv")

# %%
df
# Out:
#       Unnamed: 0  category       video_name  frame  hand_0_wrist_x  \
# 0              0         0  001_001_001.mp4      0        0.224230
# 1              1         0  001_001_001.mp4      1        0.224583
# 2              2         0  001_001_001.mp4      2        0.224691
# 3              3         0  001_001_001.mp4      3        0.225211
# 4              4         0  001_001_001.mp4      4        0.224916
# ...          ...       ...              ...    ...             ...
# 2445        2445         0  001_004_005.mp4    113        0.426188
# 2446        2446         0  001_004_005.mp4    114        0.425425
# 2447        2447         0  001_004_005.mp4    115        0.425754
# 2448        2448         0  001_004_005.mp4    116        0.425719
# 2449        2449         0  001_004_005.mp4    117        0.425831
#
#       hand_0_wrist_y  hand_0_wrist_z  hand_0_thumb_cmc_x  hand_0_thumb_cmc_y  \
# 0           0.424147    7.071476e-08            0.247098            0.405275
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  category        frame  hand_0_wrist_x  hand_0_wrist_y  \
# count  2450.000000    2450.0  2450.000000     2450.000000     2450.000000
# mean   1224.500000       0.0    61.953061        0.321916        0.449071
# std     707.398403       0.0    37.374860        0.083680        0.108281
# min       0.000000       0.0     0.000000        0.000000        0.000000
# 25%     612.250000       0.0    30.000000        0.251869        0.398368
# 50%    1224.500000       0.0    61.000000        0.303927        0.427081
# 75%    1836.750000       0.0    92.000000        0.374017        0.453161
# max    2449.000000       0.0   147.000000        0.558742        0.949364
#
#        hand_0_wrist_z  hand_0_thumb_cmc_x  hand_0_thumb_cmc_y  \
# count    2.450000e+03         2450.000000         2450.000000
# mean     1.551437e-07            0.342706            0.437649
# std      4.099320e-08            0.080371            0.111607
# ...

# %%
df["video_name"].describe()
# Out:
# count                2450
# unique                 20
# top       001_001_002.mp4
# freq                  148
# Name: video_name, dtype: object

# %%
df[df["video_name"] == "001_001_002.mp4"]
# Out:
#      Unnamed: 0  category       video_name  frame  hand_0_wrist_x  \
# 88           88         0  001_001_002.mp4      0        0.221510
# 89           89         0  001_001_002.mp4      1        0.222341
# 90           90         0  001_001_002.mp4      2        0.221909
# 91           91         0  001_001_002.mp4      3        0.221992
# 92           92         0  001_001_002.mp4      4        0.222056
# ..          ...       ...              ...    ...             ...
# 231         231         0  001_001_002.mp4    143        0.229223
# 232         232         0  001_001_002.mp4    144        0.229654
# 233         233         0  001_001_002.mp4    145        0.229973
# 234         234         0  001_001_002.mp4    146        0.230331
# 235         235         0  001_001_002.mp4    147        0.230690
#
#      hand_0_wrist_y  hand_0_wrist_z  hand_0_thumb_cmc_x  hand_0_thumb_cmc_y  \
# 88         0.430921    5.964850e-08            0.244853            0.410779
# ...

# %%
df["frame"]
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 22495    25
# 22496    26
# 22497    27
# 22498    28
# 22499    29
# Name: frame, Length: 22500, dtype: int64
